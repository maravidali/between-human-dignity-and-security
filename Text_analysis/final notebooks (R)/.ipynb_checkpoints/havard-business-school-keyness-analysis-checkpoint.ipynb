# %%
install.packages("quanteda")
install.packages("quanteda.textstats")
install.packages("quanteda.textplots")
install.packages("lubridate")
install.packages("readtext")
install.packages("corpus")
install.packages("pastecs")
install.packages("wordcloud")
install.packages("RColorBrewer")
install.packages("wordcloud2")
install.packages("tm")
install.packages("wordcloud")
install.packages("RColorBrewer")
install.packages("wordcloud2")
install.packages("ggwordcloud")
install.packages("extrafont")
install.packages("ggpubr")
# Out:
# Error in contrib.url(repos, "source"): trying to use CRAN without setting a mirror
# Traceback:
#
# 1. install.packages("ggpubr")
# 2. contrib.url(repos, "source")
# 3. stop("trying to use CRAN without setting a mirror")

# %%
library("readxl")
library(tidyverse) # metapackage of all tidyverse packages
library("writexl")
library("wordcloud")
library("RColorBrewer")
library("wordcloud2")
library("tm")
require("gridExtra")
library("pastecs")
library("quanteda")
library("quanteda.textstats")
library("quanteda.textplots")
library("readtext")
library("corpus")
library("wordcloud")
library("RColorBrewer")
library("wordcloud2")
library("SnowballC")
library("ggwordcloud")
library("extrafont")
library("ggpubr")

# %%
citizens <- read.csv("../input/hbs-keyness-full-v14/citizens_v14.csv")
councilors <- read.csv("../input/hbs-keyness-full-v14/councilors_v15.csv")

# %%
citizens$cleaned <- gsub("1%", "ενα_τις_εκατο", citizens$cleaned)
councilors$cleaned <- gsub("1%", "ενα_τις_εκατο", councilors$cleaned)

citizens$cleaned <- gsub("_πολυ", "πολυ", citizens$cleaned)
councilors$cleaned <- gsub("_πολυ", "πολυ", councilors$cleaned)

citizens$cleaned <- gsub("α πολυ τως", "απολυτως", citizens$cleaned)
councilors$cleaned <- gsub("α πολυ τως", "απολυτως", councilors$cleaned)

citizens$cleaned <- gsub("διαβιωσεις", "διαβιωσης", citizens$cleaned)
councilors$cleaned <- gsub("διαβιωσεις", "διαβιωσης", councilors$cleaned)

citizens$cleaned <- gsub("διαβιωσης", "διαβιωση", citizens$cleaned)
councilors$cleaned <- gsub("διαβιωσης", "διαβιωση", councilors$cleaned)

citizens$cleaned <- gsub("διαβιωση", "διαβιωσης", citizens$cleaned)
councilors$cleaned <- gsub("διαβιωση", "διαβιωσης", councilors$cleaned)

citizens$cleaned <- gsub("ελεγχεται", "ελεγχομενη", citizens$cleaned)
councilors$cleaned <- gsub("ελεγχεται", "ελεγχομενη", councilors$cleaned)

citizens$cleaned <- gsub("παιδια", "παιδι", citizens$cleaned)
councilors$cleaned <- gsub("παιδια", "παιδι", councilors$cleaned)

citizens$cleaned <- gsub("ελεγχομενα", "ελεγχομενη", citizens$cleaned)
councilors$cleaned <- gsub("ελεγχομενα", "ελεγχομενη", councilors$cleaned)

citizens$cleaned <- gsub("μορφωσει", "μορφωση", citizens$cleaned)
councilors$cleaned <- gsub("μορφωσει", "μορφωση", councilors$cleaned)

citizens$cleaned <- gsub("διασφαλιζει", "διασφαλιζε", citizens$cleaned)
councilors$cleaned <- gsub("διασφαλιζει", "διασφαλιζε", councilors$cleaned)

citizens$cleaned <- gsub("διασφαλιζε", "διασφαλιζει", citizens$cleaned)
councilors$cleaned <- gsub("διασφαλιζε", "διασφαλιζει", councilors$cleaned)

citizens$cleaned <- gsub("εισβολεας", "εισβολεα", citizens$cleaned)
councilors$cleaned <- gsub("εισβολεας", "εισβολεα", councilors$cleaned)

citizens$cleaned <- gsub("εισβολεα", "εισβολεας", citizens$cleaned)
councilors$cleaned <- gsub("εισβολεα", "εισβολεας", councilors$cleaned)

citizens$cleaned <- gsub("νησια", "νησι", citizens$cleaned)
councilors$cleaned <- gsub("νησια", "νησι", councilors$cleaned)

citizens$cleaned <- gsub("νησι", "νησια", citizens$cleaned)
councilors$cleaned <- gsub("νησι", "νησια", councilors$cleaned)

citizens$cleaned <- gsub("ανθρωπινα", "ανθρωπινες", citizens$cleaned)
councilors$cleaned <- gsub("ανθρωπινα", "ανθρωπινες", councilors$cleaned)

citizens$cleaned <- gsub("μουσουλμανοι", "μουσουλμανο", citizens$cleaned)
councilors$cleaned <- gsub("μουσουλμανοι", "μουσουλμανο", councilors$cleaned)

citizens$cleaned <- gsub("μουσουλμανο", "μουσουλμανοι", citizens$cleaned)
councilors$cleaned <- gsub("μουσουλμανο", "μουσουλμανοι", councilors$cleaned)

citizens$cleaned <- gsub("νομος", "νομο", citizens$cleaned)
councilors$cleaned <- gsub("νομος", "νομο", councilors$cleaned)

citizens$cleaned <- gsub("νομο", "νομος", citizens$cleaned)
councilors$cleaned <- gsub("νομο", "νομος", councilors$cleaned)

citizens$cleaned <- gsub("μορφωσε", "μορφωση", citizens$cleaned)
councilors$cleaned <- gsub("μορφωσε", "μορφωση", councilors$cleaned)

citizens$cleaned <- gsub("περιθαλψει", "περιθαλψη", citizens$cleaned)
councilors$cleaned <- gsub("περιθαλψει", "περιθαλψη", councilors$cleaned)

citizens$cleaned <- gsub("κανονας", "κανονα", citizens$cleaned)
councilors$cleaned <- gsub("κανονας", "κανονα", councilors$cleaned)

citizens$cleaned <- gsub("κανονα", "κανονας", citizens$cleaned)
councilors$cleaned <- gsub("κανονα", "κανονας", councilors$cleaned)

citizens$cleaned <- gsub("τηρηθουν", "τηρηση", citizens$cleaned)
councilors$cleaned <- gsub("τηρηθουν", "τηρηση", councilors$cleaned)

citizens$cleaned <- gsub("α κλειστες", "κλειστες", citizens$cleaned)
councilors$cleaned <- gsub("α κλειστες", "κλειστες", councilors$cleaned)

citizens$cleaned <- gsub("εξοδα", "εξοδο", citizens$cleaned)
councilors$cleaned <- gsub("εξοδα", "εξοδο", councilors$cleaned)

citizens$cleaned <- gsub("προσωρινες", "προσωρινα", citizens$cleaned)
councilors$cleaned <- gsub("προσωρινες", "προσωρινα", councilors$cleaned)

citizens$cleaned <- gsub("ποσοστο", " % ", citizens$cleaned)
councilors$cleaned <- gsub("ποσοστο", " % ", councilors$cleaned)

citizens$cleaned <- gsub("γικλειστες", "κλειστες", citizens$cleaned)
councilors$cleaned <- gsub("γικλειστες", "κλειστες", councilors$cleaned)

citizens$cleaned <- gsub("σηκωσει", "σηκωνει", citizens$cleaned)
councilors$cleaned <- gsub("σηκωσει", "σηκωνει", councilors$cleaned)

citizens$cleaned <- gsub("μικλειστες", "κλειστες", citizens$cleaned)
councilors$cleaned <- gsub("μικλειστες", "κλειστες", councilors$cleaned)

citizens$cleaned <- gsub("απελασει", "απελαση", citizens$cleaned)
councilors$cleaned <- gsub("απελασει", "απελαση", councilors$cleaned)

citizens$cleaned <- gsub("εντασσει", "ενταξη", citizens$cleaned)
councilors$cleaned <- gsub("εντασσει", "ενταξη", councilors$cleaned)

citizens$cleaned <- gsub("τηρει", "τηρηση", citizens$cleaned)
councilors$cleaned <- gsub("τηρει", "τηρηση", councilors$cleaned)

citizens$cleaned <- gsub("ενσωματωθει", "ενσωματωση", citizens$cleaned)
councilors$cleaned <- gsub("ενσωματωθει", "ενσωματωση", councilors$cleaned)

citizens$cleaned <- gsub("εγκληματιας", "εγκληματιες", citizens$cleaned)
councilors$cleaned <- gsub("εγκληματιας", "εγκληματιες", councilors$cleaned)

citizens$cleaned <- gsub("βοηθα", "βοηθεια", citizens$cleaned)
councilors$cleaned <- gsub("βοηθα", "βοηθεια", councilors$cleaned)

citizens$cleaned <- gsub("επιβαλλει", "επιβαλλουν", citizens$cleaned)
councilors$cleaned <- gsub("επιβαλλει", "επιβαλλουν", councilors$cleaned)

citizens$cleaned <- gsub("αναγνωρισμενες", "αναγνωρισμενοι", citizens$cleaned)
councilors$cleaned <- gsub("αναγνωρισμενες", "αναγνωρισμενοι", councilors$cleaned)

# %%
citizen_labels <- c(rep('citizen',nrow(citizens)))

councilors_labels <- c(rep('councilor',nrow(councilors)))

# %%
citizens_for_combined <- citizens %>% select('Anonymous_id','cleaned','Q26_edu','pol_orient','Q29_income','Q10_c_post','treat1')
citizens_for_combined['citizen_or_councilor'] = citizen_labels

councilors_for_combined <- councilors %>% select('id_anonymous','cleaned','Q26_edu','pol_orient_x','Q29_income','Q10_c','treat1')
councilors_for_combined['citizen_or_councilor'] = councilors_labels

# %%
colnames(councilors_for_combined) <- c('Anonymous_id','cleaned','Q26_edu','pol_orient','Q29_income','Q10_c_post','treat1','citizen_or_councilor')

# %%
councilors_for_combined$Q10_c_post <- as.numeric(as.character(councilors_for_combined$Q10_c_post))
# Out:
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”

# %%
combined <- bind_rows(citizens_for_combined, councilors_for_combined)

# %%
corp_councilors <- corpus(c(councilors$cleaned))
corp_citizens <- corpus(c(citizens$cleaned))
corp_combined <- corpus(c(combined$cleaned))

# %%
stop_words <- read_excel("../input/stopwords/stopwords_GR.xlsx", sheet = 'stopwords')
stop_words <- c(stop_words$word)

stop_words <-  c(stop_words, "μου","των","στις","ως","τετοια","διοτι","λογο","ειχα","μπορει","μας","μεσα","μεσου","και","να","τα","με","τον","τους",
               "σε","θα","οι","ειναι","καθως","στην","στο","γιατι","επειδη","αφου","στα","στον","θεωρουμε","δεν","καμια","δομ","του",
               "ομως","πληθυσμο","της","απο","ισχυρα","εχει","ζησει","οχι","για","αποτελει","κυριως","εχει","εν","κι","την","το","κυριως",
               "εκτος","επιπεδα","οτι","εδω","υποστηριζα","φυσικα","σχετικα","συμβαν","εδω","ειτε","μια","δε","ας","καθε","μαζι","ον","στ","τοπ",
               "κραταει","θελαμε","γινανε","μονα","θελει","μεριας","δεχεται","κατοικει","ερχεται","ενταξει","θεωρει","καν","χρειαζεστε","προσωπα","δινει",
               "ερθει","υποστηριξει","καταστασεις","υπολοιπα","βρισκανε","φιλοξενουμενο","πιστευει","λογης","γινει","μονη","υποστηριξα","προσωπικα","πιστευοντας",
               "χρειαζεται","καταστασεων","κανενα","μερα","λα","θες","κοσμικου","αφορα","κλπ","αν","στοιχεια","πρεπει","περιπτωσεις","πολλα","δικα","ηρθα","ουτε",
               "πρωτα","λιγα","τη","επιπλεον","διαφορετικα","οπως","οταν","δευτερη","κοσμο","δημος","πληρως","δινεται","ειμαστε","της","κατα","καποια","πραγμα","τρ",
               "οποια","φιλοξενει","μεχρι","τις","εφοσον","προκειμενου","συστημα","κεντρα","αδυνατο","κυριαρχει","αιτησεις","αυτην","εως","μονον","λαβει",
               "ζηταγαν","δυνατη","ζηταγα","ουσιαστικα","τωρα","συμβαινει","προσπαθεια","αυτα","αλλες","μεγαλες","πληρη","λυσει","τελος","ετσι","δηλωση","μην","σημαντικα","λαθος","εννοια",
               "δυναμει","ζω","υπαρξει","ετη","θεωρειται","ηταν","εναντι","ειδη","εγκατασταθει","οσο","χρονια","καταλληλα","που","τεκνα","κερκυρα","βασει","ατομα","εμπειρια","εκει","δηλαδη",
               "απολυτα","ακομα","φυγει","νομιζω","τουλαχιστον","δεδομενα","αλλα","επιθυμει","σχολη","θετικα","συνολικα","μακρα","εντελως","καθολου","πολιτες","φθανει","φευγουν","υποδεχθει","υπαρχει",
                "τυπου","συναφη","υ","παει","τροπο","ελεγα","ερωτηματολογιο","πολεις","δυο","γενικα","φιλοξενιας","ς","υς","πηγαινα","επιλογες","ωστε","διαδ","ομορα","μεν","πανε","ζει","ορι",
                "θεμα","φορα","σωστα","αριθμο","ζητα","ποσοστα","μπαιναν","υπηρχαν","προσπαθει","τυπικη","σπιτι","προσπαθει","μες","ξεραμε","βραν","μιλαει","σχεσει","μεινανε","ενω","χωρα","προσφυγας",
                 "μεταναστες","προυποθεσεις","διαμονη","λειτουργει","φερανε","παρεχει","αντιμετωπισει","προκειται","σκοπια","νεα","εγω","εκτη","ελευθερα","δοθει",
                "στηριξει","μαζα","ιδια","εισερχεται","επρπε","γνωριζα","δυστυχως","αιτουντα","φυγανε","υποδοχη","διαφωνεις","οντως","τελει","αντιθετρα","παραμονες","ιστο","σιγουρα","ερευνα","παιρναμε",
                 "πλεον","μαθαμε","αντιμετωπιζαν","προκαλει","συγκεκριμενα","ασυλα","ελαχιστα","ειδα","βλεπει","απολυτως","επιστρεψουμε","ερωτησεις","δρασεις","ζητημα","διαμενουν","ροες","προσφεραν",
                 "πληρωναν","φιλοξενουμενοι","διαμενουν","ελλαδα","ελληνας","περιοχες","βασικα","επρεπε","στηριζα","προερχεται","ξενα","αρχας","δεχτει","υποχρεωσεις","βοηθεια","περισσοτερα","διαφορα",
                "ζωνες","ελεγχαν","χωρανε","αρκετα","κατοικια","αμεσα","ορο","διαφωνω","γνωριζει","μεγαλα","παρολα","κτλ","α","'","αρα","τυχη","πω","φτιαχτε","πραξει","τυχει","τριτα","σειρα","συνεχιζει",
                "ουτως","ουσια","οποιοδηποτε","ομαδα","λεγεται","επιτρεπει","λεξεις","απαντες","αντιστοιχα","στειλει","στοχο","χαρακτηρα","ντρεπεστε","κομματι","κυνηγαει","ανθρωπο","ετοιμο","αποκτησει",
                "πλαισια","αυξημενες","αντιθετα","κυριο","καταρχας","εξυπηρετησουν","απεναντι","πτυχιο","συμπληρωσα","σουβλιου","επομενως","ιδιαιτερα","μεινει","λοιπον","μπει","απαντησεις","προτασεις",
                "ερωτημα","ουδεν","ακολουθει","πολλου","αλλαξει","σημασια","βιωνουμε","αποτελειται","αιτημα","ωρα","αφηνει","παταει","αποψεις","απονομη","αποδοση","χρηζουν","αυξαναν","νιωθει","οσ","ος",
                "μον","νε","εχ","λογ","τες","δι","ις","παν","βλεπε","πρεπε","ξερα","φεραν","μιλα","μερη","λτ","γτ","σχεδον","φευγανε","βαζει","τχα","ες","δνα","δν","απ","δειχνει","τελειως","δει","δομη",
                "δομες","φτιαχτει","γεματα","κατασκευες","περνα","ακολουθανε","οδηγει","υποψη","διαθετει","δηθεν","επικρατει","ιαπωνια","ευρυτερη","παραπανω")




stop_words_bigrams = c(stop_words, "μου","των","στις","ως","τετοια","διοτι","λογο","ειχα","μπορει","μας","μεσα","μεσου","και","να","τα","με","τον","τους",
               "σε","θα","οι","ειναι","καθως","στην","στο","γιατι","επειδη","αφου","στα","στον","θεωρουμε","δεν","καμια","δομ","του",
               "ομως","πληθυσμο","της","απο","ισχυρα","εχει","ζησει","οχι","για","αποτελει","κυριως","εχει","εν","κι","την","το","κυριως",
               "εκτος","επιπεδα","οτι","εδω","υποστηριζα","φυσικα","σχετικα","συμβαν","εδω","ειτε","μια","δε","ας","καθε","μαζι","ον","στ","τοπ",
               "κραταει","θελαμε","γινανε","μονα","θελει","μεριας","δεχεται","κατοικει","ερχεται","ενταξει","θεωρει","καν","χρειαζεστε","προσωπα","δινει",
               "ερθει","υποστηριξει","καταστασεις","υπολοιπα","βρισκανε","φιλοξενουμενο","πιστευει","λογης","γινει","μονη","υποστηριξα","προσωπικα","πιστευοντας",
               "χρειαζεται","καταστασεων","κανενα","μερα","λα","θες","κοσμικου","αφορα","κλπ","αν","στοιχεια","πρεπει","περιπτωσεις","πολλα","δικα","ηρθα","ουτε",
               "πρωτα","λιγα","τη","επιπλεον","διαφορετικα","οπως","οταν","δευτερη","κοσμο","δημος","πληρως","δινεται","ειμαστε","της","κατα","καποια","πραγμα","τρ",
               "οποια","φιλοξενει","μεχρι","τις","εφοσον","προκειμενου","συστημα","κεντρα","αδυνατο","κυριαρχει","αιτησεις","αυτην","εως","μονον","λαβει",
               "ζηταγαν","δυνατη","ζηταγα","ουσιαστικα","τωρα","συμβαινει","προσπαθεια","αυτα","αλλες","μεγαλες","πληρη","λυσει","τελος","ετσι","δηλωση","μην","σημαντικα","λαθος","εννοια",
               "δυναμει","ζω","υπαρξει","ετη","θεωρειται","ηταν","εναντι","ειδη","εγκατασταθει","οσο","χρονια","καταλληλα","που","τεκνα","κερκυρα","βασει","ατομα","εμπειρια","εκει","δηλαδη",
               "απολυτα","ακομα","φυγει","νομιζω","τουλαχιστον","δεδομενα","αλλα","επιθυμει","σχολη","θετικα","συνολικα","μακρα","εντελως","καθολου","πολιτες","φθανει","φευγουν","υποδεχθει","υπαρχει",
                "τυπου","συναφη","υ","παει","τροπο","ελεγα","ερωτηματολογιο","πολεις","δυο","γενικα","φιλοξενιας","ς","υς","πηγαινα","επιλογες","ωστε","διαδ","ομορα","μεν","πανε","ζει","ορι",
                "θεμα","φορα","σωστα","αριθμο","ζητα","ποσοστα","μπαιναν","υπηρχαν","προσπαθει","τυπικη","σπιτι","προσπαθει","μες","ξεραμε","βραν","μιλαει","σχεσει","μεινανε","ενω")

st = c("μουσουλμανοι_μουσουλμανοι","αναλογα_αναλογα","απεναντι_παιδια","ανθρωπια_τοπικη","ανθρωπια_τουρκια","παιδια_ενταξη",
      "κλειστες_ανθρωπια","διαβιωση_σεβασμο","ανθρωπια_ανθρωπια","καθετα_αντιθετα","ανθρωπια_κοινωνια","εξετασει_ασυλο","αιτημα_ασυλο","χορηγηση_ασυλο",
      "πραγματικος_λαθρο","ομαλα_κοινωνια","παροχες_ασυλο","πραγματικος_εμπολεμη","βοηθα_ανθρωπια","πυλες_εισοδο","5_%","ανοικτη_κλειστες",
      "λυνεται_προβλημα","ανθρωπια_παρανομα","προβλημα_προβλημα","ασυλο_επιστρεφανε","ανθρωπια_πραγματικος","νομιμα_πυλες","κοινωνια_οικονομικη",
      "διαβιωση_ανθρωπια","βοηθα_οικονομικοι","κλειστες_ακατοικητα","ανδρες_γυναικα","στρατος_εκκλησια","ανθρωπινες_αξιοπρεπεια","πολεμος_οικονομικοι",
      "μουσουλμανοι_μουσουλμανοι","αναλογα_αναλογα","λαθρο_λαθρο","απεναντι_παιδια","ανθρωπια_τοπικη","ανθρωπια_τουρκια")

# %%
toks <- citizens$cleaned %>% tokens %>% 
  tokens_remove(pattern = phrase(c(stop_words,st,stop_words_bigrams)), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(c(stop_words,st,stop_words_bigrams)), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 2)

dfmat <- 
toks_ngram %>%
tokens_remove(c(stop_words,st,stop_words_bigrams)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat)

# %%
toks <- councilors$cleaned %>% tokens %>% 
  tokens_remove(pattern = phrase(c(stop_words,st,stop_words_bigrams)), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(c(stop_words,st,stop_words_bigrams)), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 2)

dfmat <- 
toks_ngram %>%
tokens_remove(c(stop_words,st,stop_words_bigrams)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat)

# %%
toks <- citizens$cleaned %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words_bigrams), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 2)

dfmat <- 
toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat)

# %%
toks <- councilors$cleaned %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words_bigrams), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 2)

dfmat <- 
toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat)

# %%
toks <- combined$cleaned %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words_bigrams), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- 
toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_3 <- textstat_frequency(dfmat)

# %%
set.seed(1234) # for reproducibility 

options(repr.plot.width=12, repr.plot.height=18)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, vjust = 1, size = 40)) + ggtitle("Πολίτες")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, vjust = -14, size = 40)) + ggtitle("Δημοτικοί σύμβουλοι")

plot3 <- ggwordcloud(fr_3$feature, fr_3$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, vjust = -4, size = 40)) + ggtitle("Δημοτικοί σύμβουλοι και πολίτες")

grid.arrange(plot1, plot2, nrow=2)
# Out:
# Some words could not fit on page. They have been removed.
#
# Some words could not fit on page. They have been removed.

# %% [markdown]
# ## Political orientation

# %%
citizens$left_or_right = with(citizens, ifelse(pol_orient >= 5, "Right-wing citizens", "Left-wing citizens"))
councilors$left_or_right = with(councilors, ifelse(pol_orient_x >= 5, "Right-wing councilors", "Left-wing councilors"))
combined$left_or_right = with(combined, ifelse(pol_orient >= 5, "Δεξιοί", "Αριστεροί"))

citizens$edu_level = with(citizens, ifelse(Q26_edu == "Πτυχίο ΑΕΙ"|Q26_edu == "Μεταπτυχιακό ή/ και Διδακτορικό Δίπλωμα", "Πολίτες - Υψηλή εκπαίδευση", "Πολίτες - Χαμηλή εκπαίδευση"))
councilors$edu_level = with(councilors, ifelse(Q26_edu == "Πτυχίο ΑΕΙ"|Q26_edu == "Μεταπτυχιακό ή/ και Διδακτορικό Δίπλωμα", "Δημοτικοί Σύμβουλοι - Υψηλή εκπαίδευση", "Δημοτικοί Σύμβουλοι - Χαμηλή εκπαίδευση"))
combined$edu_level = with(combined, ifelse(Q26_edu == "Πτυχίο ΑΕΙ"|Q26_edu == "Μεταπτυχιακό ή/ και Διδακτορικό Δίπλωμα", "Υψηλή εκπαίδευση", "Χαμηλή εκπαίδευση"))


right_citizen_or_councilor = combined[combined$pol_orient >= 5,]
right_citizen_or_councilor$citizen_or_councilor = with(right_citizen_or_councilor, ifelse(citizen_or_councilor == "citizen", "Right-wing citizens", "Right-wing councilors"))

left_citizen_or_councilor = combined[combined$pol_orient < 5,]
left_citizen_or_councilor$citizen_or_councilor = with(left_citizen_or_councilor, ifelse(citizen_or_councilor == "citizen", "Left-wing citizens", "Left-wing councilors"))


combined$citizen_or_councilor_greek = with(combined, ifelse(citizen_or_councilor == "citizen", "Citizens", "Councilors"))

# %%
set.seed(1234) # for reproducibility 


corp_inaug <- corpus(right_citizen_or_councilor, text_field = "cleaned")
docid <- paste(right_citizen_or_councilor$citizen_or_councilor, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)


dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$citizen_or_councilor)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Right-wing councilors")

x = c('local','local_community','controls','society','integration','council','tourism','state','permanent','integration_local','benefits','commensurate','security','assimilation','fair','raises',
      'relationships','local_self-government','infrastructure','proper','smooth','remunerative','one_in_a_hundred','uninhabited','humane','assimilate','free','adequate','work','institutions')

tstat1[1:30,]$feature = x

x = c('violence','germany','respect','thoughts','corruption','men','neighbor','web','racists','child','real','invader','europe','non_governmental_organizations','heavy','criminals','greek','criminality',
      'national','entitled','war','women','right','war','homeland','deportation','subsidy','allowance','respected','pseudo','illegal')

tstat1[1709:1739,]$feature = x

options(repr.plot.width=17, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.14, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())
# Out:
# Warning message:
# “NA is replaced by empty string”

# %%
tstat1['diff'] <- abs(tstat1$n_target - tstat1$n_reference)
tstat1['addition'] <- tstat1$n_target + tstat1$n_reference

# %%
my_function <- function(x){
    msr <- -log(1/(abs(x) + 1e-9))
    
    return (msr)
    }

# %%
tstat1['msr'] <- lapply(tstat1$diff, my_function)
tstat1['final_msr'] <- tstat1$msr * tstat1$addition
# Out:
# Warning message in `[<-.data.frame`(`*tmp*`, "msr", value = list(3.7135720667287, :
# “provided 1739 variables to replace 1 variables”

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(right_citizen_or_councilor[right_citizen_or_councilor$citizen_or_councilor == "Right-wing citizens",], text_field = "cleaned")
docid_1 <- paste(right_citizen_or_councilor[right_citizen_or_councilor$citizen_or_councilor == "Right-wing citizens",]$citizen_or_councilor, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)

dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)

x = c('greek','pseudo','closed','asylum','society','real','child','war','economic','problem','europe','illegal','family','deportation','non_governmental_organisations','war','turkey','controlled',
      'conditions','%','homeland','education','respected','jobs','law','integration','islands','right','language','money','legal','unfair','culture','customs','small','allowance','muslims','pay','syria',
      'governments','morals','humane','european_union','schools','strict','needs','women','security','religion','income','dignity','culture','moral_customs','infrastructure','livelihood','army','one_of_a_hundred',
      'job','joining','border','places','entitled','closed_controlled','national','greek_society','crime','papers','health','temporary','benefits','moment','origin','criminal','norm','conduct','christian',
      'international','minors','safe','police','respect','heavy','management','afghanistan','proportions','space','capability','invader','organizations','criteria','greek_language','compliance',
      'living_conditions','identity','mandatory','majorities','men','interests','easy','organized','respected','entitled_asylum','returns','souls','nowhere','religious','gave','custodial','penal','open',
      'incoming','uninhabited_islands','documents','turned','value')

fr_1$feature[1:length(x)] = x


corp_inaug_2 <- corpus(right_citizen_or_councilor[right_citizen_or_councilor$citizen_or_councilor == "Right-wing councilors",], text_field = "cleaned")
docid_2 <- paste(right_citizen_or_councilor[right_citizen_or_councilor$citizen_or_councilor == "Right-wing councilors",]$citizen_or_councilor, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)

dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)

x = c('society','local','closed','local_society','integration','Greek','asylum','problem','security','integration','economic','infrastructure','conditions','proportionate','one_hundredth','small',
  'real','jobs','benefits','education','children','health','controls','family','governments','livelihood','muslims','schools','normal','suitable','needs','culture','border','europe','strict',
  '%','plans','turkey','army','language','law','administration','unfair','criteria','exit','entrance','facilities','tourist','council','temporary','locations','permanent','pseudo','state','controlled',
  'entry_exit','european_union','humane','reciprocating','money','compensatory','customs','syria','compliance','policing','islands','religion','integration_local','indigenous','territory','space',
  'program','allocation','tourism','services','police','war','quotas','compensatory_benefits','unemployment','non_governmental_organisations','care','services','resources','remuneration',
  'culture','measures','living_conditions','severe','legal','enormity','greek_society','ghettoization','production','self-governance','local_self-governance','open','lesson','dignity','reinforcements',
'assimilation','fair','relationships','shares','ethics','ethics_customs','organizations','community','Greek_language','raises','hirings','gradual','business','recruitment','necessary',
'construction','easy','coherence','responsibility','assimilated','strict_criteria','difficult','%_one_of_a_hundred','humanitarian','treatment','religious','work','psychological','paradigm')

fr_2$feature[1:length(x)] = x



options(repr.plot.width=10, repr.plot.height=15)


plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-2)) + ggtitle("Right-wing citizens")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Right-wing councilors")

grid.arrange(plot1, plot2, nrow=2)
# Out:
# Warning message:
# “NA is replaced by empty string”
# Warning message:
# “NA is replaced by empty string”
# Some words could not fit on page. They have been removed.
#
# Some words could not fit on page. They have been removed.

# %%
set.seed(1234) # for reproducibility 


corp_inaug <- corpus(left_citizen_or_councilor, text_field = "cleaned")
docid <- paste(left_citizen_or_councilor$citizen_or_councilor, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$citizen_or_councilor)


tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Left-wing councilors")

x = c('local','local_society','state','integration','reliables','security','assimilation','integration_local','positions','records','permanent','residence','houses','proportional','percent',
      'exchanges','reactions','distances','basic','doctors','ensures','national','adequate','severe','unit','%','governments','professional','employment','remunerative_benefits')

tstat1[1:30,]$feature = x

x = c('real','dignity','culture','international','assimilated','medical_care','due','illegal','prisons','psychological','transparency','entry_exit','permanent','forms','organization','racists',
      'responsible','needs','asylum','locations','apartment','pseudo','medicinal','exit','religion','solidarity','web','war','open','entrance','pay')

tstat1[855:885,]$feature = x

options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 4, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())
# Out:
# Warning message:
# “NA is replaced by empty string”

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(left_citizen_or_councilor[left_citizen_or_councilor$citizen_or_councilor == "Left-wing citizens",], text_field = "cleaned")
docid_1 <- paste(left_citizen_or_councilor[left_citizen_or_councilor$citizen_or_councilor == "Left-wing citizens",]$citizen_or_councilor, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)

dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()


fr_1 <- textstat_frequency(dfmat_1)

x = c('society','humane','living conditions','dignity','Greek','education','child','asylum','living_conditions','economic','problem','right','integration','work','needs','school','open','infrastructure',
      'closed','health','family','europe','human_conditions','money','places','possibility','culture','real','small','language','unfair','security','european_union','care','program','governments','respect',
      'necessities','pay','proper','management','join','war','dignity_conditions','churches','international','input','education','rule','greek_society','open','proportionate','community','controlled','law',
      'access','organizations','non_governmental_organizations','human_rights','benefits','war','women','dignity_of_living','web','solidarity','integration_society','exit','normal','religion','difficult','kids_school','papers','police',
      'organized','medical','resources','facilities','culture','benefits','reinforcements','work','update','plans','fear','medical','stealth','apartment','moment','permanent','racists','minors','transparency',
      'forms','camps','organization','responsible','integration_society','observance','entry_exit','customs','homeland','responsibilities','services','medical_care','illegal','education','prisons','assimilated',
      'funds','psychological','ought','secured','opportunities','care','learning','%','state','adults','healthy','urban','respect','morals','abide','participated','gave','covered','secured','villages','islands')

fr_1$feature[1:length(x)] = x



corp_inaug_2 <- corpus(left_citizen_or_councilor[left_citizen_or_councilor$citizen_or_councilor == "Left-wing councilors",], text_field = "cleaned")
docid_2 <- paste(left_citizen_or_councilor[left_citizen_or_councilor$citizen_or_councilor == "Left-wing councilors",]$citizen_or_councilor, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)

dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)

x = c('society','local','conditions','integration','humane','local_society','security','economics','livelihood','open','state','greek','schools','education','governments','dignity','respective','child',
      'jobs designs','benefits','human_conditions','suitable','sanitary','health','european_union','seriously','recruitment','facilities','management','acceptance','needs','europe','compensatory',
      'maintenance','organized','smooth','reliable','services','employment','dignity_conditions','responsibilities','professional','capacity','essentials','records','stay','reinforcements','rule','care',
      'integration_local','unit','integration_society','criteria','positions','measures','custody','easy','military','permanent','urban','gradual','assimilation','law','houses','negative','ghettoization',
      'difficult','basic','residents','compensating_benefits','culture','controlled','sanitary','program','care','respect_humanity','regular_integration','safe','budget','real','dignity_of_living','benefits',
      'learning','language','ethics','customs','locales','ethics','customs','ghetto','reactions','villages','surveillance','churches','hospitals','organizations','inform','non_governmental_organizations',
      'mandated','temporary','legal','implemented','overcome','adequate','poverty','state','doctors','enormous','distances','rewarding','rewarding_benefits','secures','barter','burden','war','unaccompanied',
      'overcome','sufficient','poverty','state','doctors','enormity','distances','rewarding','rewarding_benefits','ensure','exchanges','burden','war','unaccompanied','unaccompanied_child','national','crisis',
      'proportionality','region','profile','plans_join','logic','find','scientists','host','group','construction','construction_infrastructure','rural','symbol','suitable_infrastructure','health_conditions',
      'council','piece')

fr_2$feature[1:length(x)] = x


options(repr.plot.width=10, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Left-wing citizens")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-3)) + ggtitle("Left-wing councilors")

grid.arrange(plot1, plot2, nrow=2)
# Out:
# Warning message:
# “NA is replaced by empty string”
# Warning message:
# “NA is replaced by empty string”
# Some words could not fit on page. They have been removed.
#
# Some words could not fit on page. They have been removed.

# %%
set.seed(1234) # for reproducibility 


corp_inaug <- corpus(combined, text_field = "cleaned")
docid <- paste(combined$citizen_or_councilor_greek, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$citizen_or_councilor_greek)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Councilors")

x = c('open','germany','bad','passed','turned','souls','value','takes','credentials','neighbor','gave','invader','real','permanent','criminal','racists','entitled','women','heavy','web','Greek','homeland',
      'criminals','criminality','national','belligerent','war','deport','respect','allowance','pay','pseudo','illegal')

tstat1[2770:2802,]$feature = x

x = c('local','local_society','state','control','integration','council','permanent','society','assimilation','reliable','tourist','security','appropriate','local_integration','positions','benefits','fair',
      'integration_local','sufficient','records','team','local_self-government','one_in_hundred','humanitarian','responses','basic','doctors','ensure','national','mandatory')

tstat1[1:30,]$feature = x


options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.64, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(combined[combined$citizen_or_councilor_greek == "Πολίτες",], text_field = "cleaned")
docid_1 <- paste(combined[combined$citizen_or_councilor_greek == "Πολίτες",]$citizen_or_councilor_greek, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)

dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()



fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(combined[combined$citizen_or_councilor_greek == "Δημοτικοί Σύμβουλοι",], text_field = "cleaned")
docid_2 <- paste(combined[combined$citizen_or_councilor_greek == "Δημοτικοί Σύμβουλοι",]$citizen_or_councilor_greek, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)

dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)



options(repr.plot.width=10, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Πολίτες")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι")

grid.arrange(plot1, plot2, nrow=2)

# %%
set.seed(1234) # for reproducibility 


corp_inaug <- corpus(councilors, text_field = "cleaned")
docid <- paste(councilors$left_or_right, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()


dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$left_or_right)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Right-wing councilors")

x = c('muslims','closed','borders','turkey','controls','entry','exit','real','entry_exit','unlawful','culture','unemployment','religion','quotas','tourism','tourist','raises','local','asylum','Syria',
      'strictly','uninhabited','uninhabited','assimilate','free','war','work','usa','origin','engine')

tstat1[1:length(x),]$feature = x

x = c('churches','burden','overcome','smooth_integration','governments','child','women','duty','achieve','schools','dignity_conditions','organized','stay','houses','care','money','exchanges',
      'unaccompanied_child','ghetto','budgeting','human_respect','poverty','living_conditions','subsistence','human_conditions','health','employment','conditions','state','right','respect','dignity',
      'open','humane')

tstat1[290:323,]$feature = x

options(repr.plot.width=12, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.24, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(councilors[councilors$left_or_right == "Δεξιοί Δημοτικοί Σύμβουλοι",], text_field = "cleaned")
docid_1 <- paste(councilors[councilors$left_or_right == "Δεξιοί Δημοτικοί Σύμβουλοι",]$left_or_right, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)

dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()


fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(councilors[councilors$left_or_right == "Αριστεροί Δημοτικοί Σύμβουλοι",], text_field = "cleaned")
docid_2 <- paste(councilors[councilors$left_or_right == "Αριστεροί Δημοτικοί Σύμβουλοι",]$left_or_right, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)

dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)



options(repr.plot.width=10, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Δεξιοί δημοτικοί σύμβουλοι")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Αριστεροί δημοτικοί σύμβουλοι")

grid.arrange(plot1, plot2, nrow=2)

# %%
set.seed(1234) # for reproducibility 


corp_inaug <- corpus(citizens, text_field = "cleaned")
docid <- paste(citizens$left_or_right, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()


dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$left_or_right)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Right-wing citizens")

x = c('pseudo','deport','closed','illegal','subsidy','turkey','real','syria','legal','%','closed_controlled','respected','homeland','non_governmental_organizations','greek','muslim','islands',
      'invader','war','strict','entitled','embassy','controlled','national','afghanistan','uninhabited_islands','europe','uninhabited','islam','ethics','origin','customs','customs','interests',
      'entitle_asylum','returns','border','questions','alteration','men','east','indigenous','enforce','unchecked','law','distances','cost','real_war','asylum','asylum_practical','say','irregularities',
      'christians','indifference','armenia','incoming','examine','one_of_a_hundred','army','deportation_sneak','deterrence','left','intentions','clear','steps','classes','crime','safe','primary','identity',
      'athens','demands','proved','destroy','china','attitudes','family','otherwise','africa','inflows','impose','orthodox','fanatics','nowhere','majorities','cares','pakistan','tolerated','persecuted',
      'indoors','colonization','islamists','pseudo_invader','pseudo_pious','legally_wrong','believes','standards','somalia','pious','religion','turned','bothers','re-promotions','says','overcome',
      'traditions','endangered','attitudes','pakistan','delinquent_behavior','points','mandatory','mandatory','violent','germany','respected','fact','declared','mercy','wealth','replacement','distant',
      'rape','france','custom_religion','greek_greek','exceptions')

tstat1$feature[1:length(x)] = x

x = c('assimilated','medical_care','psychological','education','human_rights','schools','medical','needs','open','community','apartment','health','care','transparency','information','possibility',
      'churches','appropriate','necessities','program','dignity_conditions','education','human_conditions','society','open','conditions','living_conditions','dignity','humane','livelihood','destroyed')

tstat1[2560:2590,]$feature = x

options(repr.plot.width=12, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.17, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(citizens[citizens$left_or_right == "Right-wing citizens",], text_field = "cleaned")
docid_1 <- paste(citizens[citizens$left_or_right == "Right-wing citizens",]$left_or_right, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)

dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)

x = c('greek','pseudo','closed','asylum','society','real','child','war','economic','problem','europe','illegal','family','deportation','non_governmental_organizations','war','turkey','controlled',
      'conditions','%','homeland','education','respected','jobs','law','integration','islands','right','language','money','legal','unfair','culture','customs','small','allowance','muslims','pay','syria',
      'governments','morals','humane','european_union','schools','strict','needs','women','security','religion','income','dignity','culture','moral_customs','infrastructure','livelihood','army',
      'one_of_a_hundred','job','joining','border','places','entitled','closed_controlled','national','greek_society','crime','papers','health','temporary','benefits','moment','origin','criminal','norm',
      'conduct','christian','international','minors','safe','police','respect','heavy','management','afghanistan','proportions','space','capability','invader','organizations','criteria','greek_language',
      'compliance','living_conditions','identity','mandatory','majorities','men','web','easy','organized','respected','entitled_asylum','returns','souls','nowhere','religious','gave','custodial','penal',
      'open','incoming','uninhabited_islands','documents','turned','value')

fr_1$feature[1:length(x)] = x



corp_inaug_2 <- corpus(citizens[citizens$left_or_right == "Left-wing citizens",], text_field = "cleaned")
docid_2 <- paste(citizens[citizens$left_or_right == "Left-wing citizens",]$left_or_right, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)

dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)

x = c('society','humane','living','conditions','dignity','Greek','education','child','asylum','living_conditions','financial','problem','right','integration','work','needs','school','open',
      'infrastructure','closed','health','family','europe','human_conditions','money','locations','possibility','culture','real','small','language','unfair','security','european_union','care','program',
      'governments','respect','necessities','pay','proper','management','join','war','dignity_conditions','churches','international','input','education','rule','greek_society','open','proportional',
      'community','controlled','law','access','organizations','non_governmental_organizations','human_right','benefits','war','women','dignity_of_life','web','solidarity','integration_society','exit',
      'smooth','religion','difficult','kids_school','papers','police','organized','medical','resources','facilities','culture','benefits','reinforcement','work','inform','plans','fear','medical','stealth',
      'apartment','moment','permanent','racists','minors','transparency','forms','camps','organization','responsible','integration_society','compliance','entry_exit','customs','homeland','responsibilities',
      'services','medical_care','illegal','education','prisons','assimilated','funds','psychological','owed','secured','opportunities','care','learning','%','state','adults','health','urban','respected',
      'ethics','resides','participated','gave','covered','secured','villages','islands')

fr_2$feature[1:length(x)] = x


options(repr.plot.width=10, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Right-wing citizens")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Left-wing citizens")

grid.arrange(plot1, plot2, nrow=2)
# Out:
# Warning message:
# “NA is replaced by empty string”
# Warning message:
# “NA is replaced by empty string”
# Some words could not fit on page. They have been removed.
#
# Some words could not fit on page. They have been removed.

# %%
set.seed(1234) # for reproducibility 



corp_inaug <- corpus(combined, text_field = "cleaned")
docid <- paste(combined$left_or_right, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()


dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$left_or_right)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Δεξιοί")

options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.24, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(combined[combined$left_or_right == "Δεξιοί",], text_field = "cleaned")
docid_1 <- paste(combined[combined$left_or_right == "Δεξιοί",]$left_or_right, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)

dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(combined[combined$left_or_right == "Αριστεροί",], text_field = "cleaned")
docid_2 <- paste(combined[combined$left_or_right == "Αριστεροί",]$left_or_right, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)

dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=10, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Δεξιοί (Πολίτες & Δημοτικοί σύμβουλοι)")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Αριστεροί (Πολίτες & Δημοτικοί σύμβουλοι)")

grid.arrange(plot1, plot2, nrow=2)

# %% [markdown]
# ## Education

# %% [markdown]
# **Πτυχίο ΑΕΙ/Μεταπτυχιακό ή/ και Διδακτορικό Δίπλωμα VS Υπόλοιποι**

# %%
councilors_edu = councilors[councilors$Q26_edu != "Δε γνωρίζω / Δεν απαντώ",]
citizens_edu = citizens[citizens$Q26_edu != "Δε γνωρίζω / Δεν απαντώ",]
combined_edu = combined[combined$Q26_edu != "Δε γνωρίζω / Δεν απαντώ",]

# %%
set.seed(1234) # for reproducibility 



corp_inaug <- corpus(councilors, text_field = "cleaned")
docid <- paste(councilors$edu_level, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$edu_level)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Δημοτικοί Σύμβουλοι - Υψηλή εκπαίδευση")

options(repr.plot.width=15, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.14, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(councilors[councilors$edu_level == "Δημοτικοί Σύμβουλοι - Υψηλή εκπαίδευση",], text_field = "cleaned")
docid_1 <- paste(councilors[councilors$edu_level == "Δημοτικοί Σύμβουλοι - Υψηλή εκπαίδευση",]$edu_level, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)

dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(councilors[councilors$edu_level == "Δημοτικοί Σύμβουλοι - Χαμηλή εκπαίδευση",], text_field = "cleaned")
docid_2 <- paste(councilors[councilors$edu_level == "Δημοτικοί Σύμβουλοι - Χαμηλή εκπαίδευση",]$edu_level, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)

dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι - Υψηλή εκπαίδευση")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι - Χαμηλή εκπαίδευση")

grid.arrange(plot1, plot2, nrow=2)

# %%
set.seed(1234) # for reproducibility 



corp_inaug <- corpus(citizens, text_field = "cleaned")
docid <- paste(citizens$edu_level, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$edu_level)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Πολίτες - Υψηλή εκπαίδευση")

options(repr.plot.width=14, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.14, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(citizens[citizens$edu_level == "Πολίτες - Υψηλή εκπαίδευση",], text_field = "cleaned")
docid_1 <- paste(citizens[citizens$edu_level == "Πολίτες - Υψηλή εκπαίδευση",]$edu_level, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(citizens[citizens$edu_level == "Πολίτες - Χαμηλή εκπαίδευση",], text_field = "cleaned")
docid_2 <- paste(citizens[citizens$edu_level == "Πολίτες - Χαμηλή εκπαίδευση",]$edu_level, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Πολίτες - Υψηλή εκπαίδευση")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Πολίτες - Χαμηλή εκπαίδευση")

grid.arrange(plot1, plot2, nrow=2)

# %%
set.seed(1234) # for reproducibility 



corp_inaug <- corpus(combined, text_field = "cleaned")
docid <- paste(combined$edu_level, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$edu_level)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Υψηλή εκπαίδευση")

options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.18, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(combined[combined$edu_level == "Υψηλή εκπαίδευση",], text_field = "cleaned")
docid_1 <- paste(combined[combined$edu_level == "Υψηλή εκπαίδευση",]$edu_level, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(combined[combined$edu_level == "Χαμηλή εκπαίδευση",], text_field = "cleaned")
docid_2 <- paste(combined[combined$edu_level == "Χαμηλή εκπαίδευση",]$edu_level, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι & Πολίτες - Υψηλή εκπαίδευση")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι & Πολίτες - Χαμηλή εκπαίδευση")

grid.arrange(plot1, plot2, nrow=2)

# %% [markdown]
# ## Income

# %%
citizens_inc_2 = citizens
councilors_inc_2 = councilors
combined_inc_2 = combined

citizens_inc_1 = citizens
councilors_inc_1 = councilors
combined_inc_1 = combined

# %%
councilors_inc_1 = councilors[councilors$Q29_income == "Πολύ άνετα" | councilors$Q29_income == "Με μεγάλη δυσκολία",]
citizens_inc_1 = citizens[citizens$Q29_income == "Πολύ άνετα" | citizens$Q29_income == "Με μεγάλη δυσκολία",]
combined_inc_1 = combined[combined$Q29_income == "Πολύ άνετα" | combined$Q29_income == "Με μεγάλη δυσκολία",]


citizens_inc_1$inc_level = with(citizens_inc_1, ifelse(Q29_income == "Πολύ άνετα", "Πολίτες - Πολύ άνετα", "Πολίτες - Με μεγάλη δυσκολία"))
councilors_inc_1$inc_level = with(councilors_inc_1, ifelse(Q29_income == "Πολύ άνετα", "Δημοτικοί Σύμβουλοι - Πολύ άνετα", "Δημοτικοί Σύμβουλοι - Με μεγάλη δυσκολία"))
combined_inc_1$inc_level = with(combined_inc_1, ifelse(Q29_income == "Πολύ άνετα", "Πολύ άνετα", "Με μεγάλη δυσκολία"))


citizens_inc_2$inc_level = with(citizens, ifelse(Q29_income == "Πολύ άνετα"|Q29_income == "Άνετα", "Πολίτες - Υψηλό εισόδημα", "Πολίτες - Χαμηλό εισόδημα"))
councilors_inc_2$inc_level = with(councilors, ifelse(Q29_income == "Πολύ άνετα"|Q29_income == "Άνετα", "Δημοτικοί Σύμβουλοι - Υψηλό εισόδημα", "Δημοτικοί Σύμβουλοι - Χαμηλό εισόδημα"))
combined_inc_2$inc_level = with(combined, ifelse(Q29_income == "Πολύ άνετα"|Q29_income == "Άνετα", "Υψηλό εισόδημα", "Χαμηλό εισόδημα"))

# %% [markdown]
# **Πολύ άνετα VS Με μεγάλη δυσκολία**

# %%
set.seed(1234) # for reproducibility 



corp_inaug <- corpus(councilors_inc_1, text_field = "cleaned")
docid <- paste(councilors_inc_1$inc_level, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 2,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$inc_level)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Δημοτικοί Σύμβουλοι - Πολύ άνετα")

options(repr.plot.width=12, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.54, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(councilors_inc_1[councilors_inc_1$inc_level == "Δημοτικοί Σύμβουλοι - Πολύ άνετα",], text_field = "cleaned")
docid_1 <- paste(councilors_inc_1[councilors_inc_1$inc_level == "Δημοτικοί Σύμβουλοι - Πολύ άνετα",]$inc_level, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(councilors_inc_1[councilors_inc_1$inc_level == "Δημοτικοί Σύμβουλοι - Με μεγάλη δυσκολία",], text_field = "cleaned")
docid_2 <- paste(councilors_inc_1[councilors_inc_1$inc_level == "Δημοτικοί Σύμβουλοι - Με μεγάλη δυσκολία",]$inc_level, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι - Πολύ άνετα")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι - Με μεγάλη δυσκολία")

grid.arrange(plot1, plot2, nrow=2)

# %%
set.seed(1234) # for reproducibility 


corp_inaug <- corpus(citizens_inc_1, text_field = "cleaned")
docid <- paste(citizens_inc_1$inc_level, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()


dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$inc_level)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure="lr", target = "Πολίτες - Πολύ άνετα")

options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.14, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(citizens_inc_1[citizens_inc_1$inc_level == "Πολίτες - Πολύ άνετα",], text_field = "cleaned")
docid_1 <- paste(citizens_inc_1[citizens_inc_1$inc_level == "Πολίτες - Πολύ άνετα",]$inc_level, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(citizens_inc_1[citizens_inc_1$inc_level == "Πολίτες - Με μεγάλη δυσκολία",], text_field = "cleaned")
docid_2 <- paste(citizens_inc_1[citizens_inc_1$inc_level == "Πολίτες - Με μεγάλη δυσκολία",]$inc_level, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=10, repr.plot.height=14)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-6)) + ggtitle("Πολίτες - Πολύ άνετα")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-2)) + ggtitle("Πολίτες - Με μεγάλη δυσκολία")

grid.arrange(plot1, plot2, nrow=2)

# %%
set.seed(1234) # for reproducibility 


corp_inaug <- corpus(combined_inc_1, text_field = "cleaned")
docid <- paste(combined_inc_1$inc_level, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()


dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$inc_level)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = 'lr', target = "Πολύ άνετα")

options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.14, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(combined_inc_1[combined_inc_1$inc_level == "Πολύ άνετα",], text_field = "cleaned")
docid_1 <- paste(combined_inc_1[combined_inc_1$inc_level == "Πολύ άνετα",]$inc_level, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(combined_inc_1[combined_inc_1$inc_level == "Με μεγάλη δυσκολία",], text_field = "cleaned")
docid_2 <- paste(combined_inc_1[combined_inc_1$inc_level == "Με μεγάλη δυσκολία",]$inc_level, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι & Πολίτες - Πολύ άνετα")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι & Πολίτες - Με μεγάλη δυσκολία")

grid.arrange(plot1, plot2, nrow=2)

# %% [markdown]
# **Πολύ άνετα/Άνετα VS Υπόλοιποι**

# %%
set.seed(1234) # for reproducibility 


corp_inaug <- corpus(councilors_inc_2, text_field = "cleaned")
docid <- paste(councilors_inc_2$inc_level, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()


dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$inc_level)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Δημοτικοί Σύμβουλοι - Υψηλό εισόδημα")

options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.25, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(councilors_inc_2[councilors_inc_2$inc_level == "Δημοτικοί Σύμβουλοι - Υψηλό εισόδημα",], text_field = "cleaned")
docid_1 <- paste(councilors_inc_2[councilors_inc_2$inc_level == "Δημοτικοί Σύμβουλοι - Υψηλό εισόδημα",]$inc_level, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(councilors_inc_2[councilors_inc_2$inc_level == "Δημοτικοί Σύμβουλοι - Χαμηλό εισόδημα",], text_field = "cleaned")
docid_2 <- paste(councilors_inc_2[councilors_inc_2$inc_level == "Δημοτικοί Σύμβουλοι - Χαμηλό εισόδημα",]$inc_level, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι - Υψηλό εισόδημα")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι - Χαμηλό εισόδημα")

grid.arrange(plot1, plot2, nrow=2)

# %%
set.seed(1234) # for reproducibility 


corp_inaug <- corpus(citizens_inc_2, text_field = "cleaned")
docid <- paste(citizens_inc_2$inc_level, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()


dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")


dfmat1 <- dfm_group(dfmat1, groups = dfmat1$inc_level)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Πολίτες - Υψηλό εισόδημα")

options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.43, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(citizens_inc_2[citizens_inc_2$inc_level == "Πολίτες - Υψηλό εισόδημα",], text_field = "cleaned")
docid_1 <- paste(citizens_inc_2[citizens_inc_2$inc_level == "Πολίτες - Υψηλό εισόδημα",]$inc_level, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(citizens_inc_2[citizens_inc_2$inc_level == "Πολίτες - Χαμηλό εισόδημα",], text_field = "cleaned")
docid_2 <- paste(citizens_inc_2[citizens_inc_2$inc_level == "Πολίτες - Χαμηλό εισόδημα",]$inc_level, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Πολίτες - Υψηλό εισόδημα")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Πολίτες - Χαμηλό εισόδημα")

grid.arrange(plot1, plot2, nrow=2)

# %%
set.seed(1234) # for reproducibility 


corp_inaug <- corpus(combined_inc_2, text_field = "cleaned")
docid <- paste(combined_inc_2$inc_level, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()


dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 2,
  docfreq_type = "count")


dfmat1 <- dfm_group(dfmat1, groups = dfmat1$inc_level)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Υψηλό εισόδημα")

options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.14, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(combined_inc_2[combined_inc_2$inc_level == "Υψηλό εισόδημα",], text_field = "cleaned")
docid_1 <- paste(combined_inc_2[combined_inc_2$inc_level == "Υψηλό εισόδημα",]$inc_level, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(combined_inc_2[combined_inc_2$inc_level == "Χαμηλό εισόδημα",], text_field = "cleaned")
docid_2 <- paste(combined_inc_2[combined_inc_2$inc_level == "Χαμηλό εισόδημα",]$inc_level, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 25, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι & Πολίτες - Υψηλό εισόδημα")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 22, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι & Πολίτες - Χαμηλό εισόδημα")

grid.arrange(plot1, plot2, nrow=2)

# %% [markdown]
# ## Support

# %% [markdown]
# **1/2 VS 4/5**

# %%
councilors_sup = councilors[councilors$Q10_c != '3' & councilors$Q10_c != '99',]
citizens_sup = citizens[citizens$Q10_c_post != 3 & citizens$Q10_c_post != 99,]
combined_sup = combined[combined$Q10_c_post != 3 & combined$Q10_c_post != 99 & !is.na(combined$Q10_c_post),]


citizens_sup$sup_level = with(citizens_sup, ifelse(Q10_c_post == 1|Q10_c_post == 2, "Citizens - don't support", "Citizens - support"))
councilors_sup$sup_level = with(councilors_sup, ifelse(Q10_c == 1|Q10_c == 2, "Councilors - don't support", "Councilors - support"))
combined_sup$sup_level = with(combined_sup, ifelse(Q10_c_post == 1|Q10_c_post == 2, "don't support", "support"))

# %%
set.seed(1234) # for reproducibility 



corp_inaug <- corpus(councilors_sup, text_field = "cleaned")
docid <- paste(councilors_sup$sup_level, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")


dfmat1 <- dfm_group(dfmat1, groups = dfmat1$sup_level)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Councilors - support")

x = c('updated','religion','origin','addressnes','people','paratype','adjustment','roma','behavior','soul','policing','kids','strict','islands','usa','raises','tourism','law','military','real','border',
      'unemployment','temporary','tourist','economic','turkey','greek','one_of_a_hundred','asylum','closed','muslims')

tstat1[217:247,]$feature = x

x = c('living','living_conditions','dignity','dignity_conditions','integration','open','respect','society','program','accession','humane','homes','ensures','integration_society','smooth_integration',
      'money','income','stages','conditions','local_society','management','self-government','reinforcements','responsibilities','organizations','local_self-government','market','market_jobs',
      'proportionality','dignity_of_living')

tstat1[1:30,]$feature = x

options(repr.plot.width=12, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.7, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(councilors_sup[councilors_sup$sup_level == "Δημοτικοί Σύμβουλοι - Υποστηρίζουν",], text_field = "cleaned")
docid_1 <- paste(councilors_sup[councilors_sup$sup_level == "Δημοτικοί Σύμβουλοι - Υποστηρίζουν",]$sup_level, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(councilors_sup[councilors_sup$sup_level == "Δημοτικοί Σύμβουλοι - Δεν υποστηρίζουν",], text_field = "cleaned")
docid_2 <- paste(councilors_sup[councilors_sup$sup_level == "Δημοτικοί Σύμβουλοι - Δεν υποστηρίζουν",]$sup_level, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι - Υποστηρίζουν")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι - Δεν υποστηρίζουν")

grid.arrange(plot1, plot2, nrow=2)

# %%
set.seed(1234) # for reproducibility 



corp_inaug <- corpus(citizens_sup, text_field = "cleaned")
docid <- paste(citizens_sup$sup_level, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 3,
  docfreq_type = "count")

dfmat1 <- dfm_group(dfmat1, groups = dfmat1$sup_level)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Citizens - support")

x = c('livelihood','dignity','humane','conditions','living_conditions','open','education','society','dignity_conditions','human_conditions','schools','program','infrastructure','information','open',
      'access','human_rights','churches','adequate','community','suitable','health','opportunities','integration','child_school','right','ability','care','equal','volunteers')

tstat1[1:30,]$feature = x

x = c('returns','islands','foreigner','religion','uninhabited_islands','customs','armenia','morals','female_child','female','closed_controlled','christians','nowhere','alteration','afghanistan','returned',
      'respected','invader','legal','allowance','homeland','war','muslims','syria','real','closed','turkey','illegal','deportation','war','pseudo')

tstat1[2293:2323,]$feature = x



options(repr.plot.width=14, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.14, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(citizens_sup[citizens_sup$sup_level == "Πολίτες - Υποστηρίζουν",], text_field = "cleaned")
docid_1 <- paste(citizens_sup[citizens_sup$sup_level == "Πολίτες - Υποστηρίζουν",]$sup_level, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(citizens_sup[citizens_sup$sup_level == "Πολίτες - Δεν υποστηρίζουν",], text_field = "cleaned")
docid_2 <- paste(citizens_sup[citizens_sup$sup_level == "Πολίτες - Δεν υποστηρίζουν",]$sup_level, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Πολίτες - Υποστηρίζουν")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 40, vjust=-4)) + ggtitle("Πολίτες - Δεν υποστηρίζουν")

grid.arrange(plot1, plot2, nrow=2)

# %%
set.seed(1234) # for reproducibility 



corp_inaug <- corpus(combined_sup, text_field = "cleaned")
docid <- paste(combined_sup$sup_level, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 2,
  docfreq_type = "count")


dfmat1 <- dfm_group(dfmat1, groups = dfmat1$sup_level)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Υποστηρίζουν")

options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.14, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(combined_sup[combined_sup$sup_level == "Υποστηρίζουν",], text_field = "cleaned")
docid_1 <- paste(combined_sup[combined_sup$sup_level == "Υποστηρίζουν",]$sup_level, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(combined_sup[combined_sup$sup_level == "Δεν υποστηρίζουν",], text_field = "cleaned")
docid_2 <- paste(combined_sup[combined_sup$sup_level == "Δεν υποστήριξη: 1, 2",]$sup_level, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι & Πολίτες - Υποστηρίζουν")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι & Πολίτες - Δεν υποστηρίζουν")

grid.arrange(plot1, plot2, nrow=2)

# %% [markdown]
# ## Treat

# %% [markdown]
# **Exposed vs Not exposed**

# %%
councilors_treat = councilors[!is.na(councilors$treat),]
citizens_treat = citizens[!is.na(citizens$treat),]
combined_treat = combined[!is.na(combined$treat),]


citizens_treat$treat = with(citizens_treat, ifelse(treat1 == 1, "Πολίτες - Με δομή", "Πολίτες - Χωρίς δομή"))
councilors_treat$treat = with(councilors_treat, ifelse(treat1 == 1, "Δημοτικοί Σύμβουλοι - Με δομή", "Δημοτικοί Σύμβουλοι - Χωρίς δομή"))
combined_treat$treat = with(combined_treat, ifelse(treat1 == 1, "Με δομή", "Χωρίς δομή"))

# %%
set.seed(1234) # for reproducibility 



corp_inaug <- corpus(councilors_treat, text_field = "cleaned")
docid <- paste(councilors_treat$treat, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 2,
  docfreq_type = "count")


dfmat1 <- dfm_group(dfmat1, groups = dfmat1$treat)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Δημοτικοί Σύμβουλοι - Με δομή")

options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.5, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(councilors_treat[councilors_treat$treat == "Δημοτικοί Σύμβουλοι - Με δομή",], text_field = "cleaned")
docid_1 <- paste(councilors_treat[councilors_treat$treat == "Δημοτικοί Σύμβουλοι - Με δομή",]$treat, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(councilors_treat[councilors_treat$treat == "Δημοτικοί Σύμβουλοι - Χωρίς δομή",], text_field = "cleaned")
docid_2 <- paste(councilors_treat[councilors_treat$treat == "Δημοτικοί Σύμβουλοι - Χωρίς δομή",]$treat, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι - Με δομή")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι - Χωρίς δομή")

grid.arrange(plot1, plot2, nrow=2)

# %%
set.seed(1234) # for reproducibility 



corp_inaug <- corpus(citizens_treat, text_field = "cleaned")
docid <- paste(citizens_treat$treat, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 2,
  docfreq_type = "count")


dfmat1 <- dfm_group(dfmat1, groups = dfmat1$treat)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Πολίτες - Με δομή")

options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.5, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(citizens_treat[citizens_treat$treat == "Πολίτες - Με δομή",], text_field = "cleaned")
docid_1 <- paste(citizens_treat[citizens_treat$treat == "Πολίτες - Με δομή",]$treat, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(citizens_treat[citizens_treat$treat == "Πολίτες - Χωρίς δομή",], text_field = "cleaned")
docid_2 <- paste(citizens_treat[citizens_treat$treat == "Πολίτες - Χωρίς δομή",]$treat, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Πολίτες - Με δομή")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Πολίτες - Χωρίς δομή")

grid.arrange(plot1, plot2, nrow=2)

# %%
set.seed(1234) # for reproducibility 



corp_inaug <- corpus(combined_treat, text_field = "cleaned")
docid <- paste(combined_treat$treat, sep = " ")
docnames(corp_inaug) <- docid

toks <- corp_inaug %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram <- tokens_select(toks, pattern = phrase(stop_words), selection = "remove")

toks_ngram <- tokens_ngrams(toks_ngram, n = 1:2)

dfmat <- dfm(toks_ngram)

dfmat1 <- toks_ngram %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

dfmat1 <- dfm_trim(
  dfmat1,
  min_docfreq = 2,
  docfreq_type = "count")


dfmat1 <- dfm_group(dfmat1, groups = dfmat1$treat)
tstat1 <- quanteda.textstats::textstat_keyness(dfmat1, measure = "lr", target = "Με δομή")

options(repr.plot.width=11, repr.plot.height=14)

textplot_keyness(tstat1, labelsize=6, color = c('blue','red'), margin = 0.5, n = 25) +
  theme(legend.key.height = unit(1, 'cm'), 
        legend.key.width = unit(1, 'cm'), 
        legend.text = element_text(size=14)) +
        
        theme(axis.line = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_line(),
        panel.border = element_blank(),
        panel.background = element_blank())

# %%
set.seed(1234) # for reproducibility 

corp_inaug_1 <- corpus(combined_treat[combined_treat$treat == "Με δομή",], text_field = "cleaned")
docid_1 <- paste(combined_treat[combined_treat$treat == "Με δομή",]$treat, sep = " ")
docnames(corp_inaug_1) <- docid_1



toks_1 <- corp_inaug_1 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_1 <- tokens_select(toks_1, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_1 <- tokens_ngrams(toks_ngram_1, n = 1:2)


dfmat_1 <- 
toks_ngram_1 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_1 <- textstat_frequency(dfmat_1)



corp_inaug_2 <- corpus(combined_treat[combined_treat$treat == "Χωρίς δομή",], text_field = "cleaned")
docid_2 <- paste(combined_treat[combined_treat$treat == "Χωρίς δομή",]$treat, sep = " ")
docnames(corp_inaug_2) <- docid_2



toks_2 <- corp_inaug_2 %>% tokens %>% 
  tokens_remove(pattern = phrase(stop_words), valuetype = 'fixed')

toks_ngram_2 <- tokens_select(toks_2, pattern = phrase(stop_words_bigrams), selection = "remove")

toks_ngram_2 <- tokens_ngrams(toks_ngram_2, n = 1:2)


dfmat_2 <- 
toks_ngram_2 %>%
tokens_remove(c(stop_words,st)) %>%
dfm()

fr_2 <- textstat_frequency(dfmat_2)


options(repr.plot.width=12, repr.plot.height=15)

plot1 <- ggwordcloud(fr_1$feature, fr_1$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι & Πολίτες - Με δομή")

plot2 <- ggwordcloud(fr_2$feature, fr_2$frequency, scale = c(4, 1),
max.words = 100, random.order = F, random.color = FALSE,
rot.per = 0, colors = "black", ordered.colors = FALSE, shape = 'circle') + theme(plot.title = element_text(hjust = 0.5, size = 30, vjust=-4)) + ggtitle("Δημοτικοί σύμβουλοι & Πολίτες - Χωρίς δομή")

grid.arrange(plot1, plot2, nrow=2)
